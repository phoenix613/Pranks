# %%
# EX 1
gray = range(0, 256, 5)
I = [391, 395, 404, 412, 425, 432, 435, 439, 444, 445, 
     445, 445, 443, 441, 439, 435, 430, 426, 422, 414,
     409, 403, 397, 386, 381, 372, 365, 358, 347, 339,
     334, 324, 317, 311, 302, 297, 291, 285, 280, 277,
     273] + [ 252, 249, 244, 242, 239, 236, 233, 231, 229, 
     227, 226]

import matplotlib.pyplot as plt
import numpy as np
plt.plot(gray, I)
I_mirrored = [445+(445-I[i]) for i in range(10)] + I[10:]
plt.plot(gray, I_mirrored)
plt.show()
plt.plot(gray, [2*np.arcsin(x/max(I_mirrored)) for x in I_mirrored])
plt.show()

# %%
#EX 2 (WRONG)
I = [
    290, 291, 292, 295, 297, 298, 300, 302, 303, 305,
    308, 309, 312, 313, 316, 319, 322, 323, 326, 328,
    330, 332, 333, 334, 335, 336, 335, 334, 333, 332,
    330, 327, 324, 321, 317, 313, 309, 303, 299, 295,
    284, 279, 272, 261, 256, 247, 239, 226, 220, 210,
    198, 190
]
I_mirrored = [336+(336-I[i]) for i in range(25)] + I[25:]
plt.plot(gray, I)
plt.plot(gray, I_mirrored)
plt.show()
plt.plot(gray, [2*np.arcsin(x/max(I_mirrored)) for x in I_mirrored])
plt.show()

# %%
I = [
     37,  37,  38,  40,  45,  51,  58,  66,  72,  78,
     84,  90,  96, 101, 103, 110, 117, 121, 129, 136,
    142, 150, 154, 159, 166, 172, 172, 178, 182, 188,
    191, 196, 201, 205, 208, 210, 212, 216, 213, 214, 
    216, 216, 216, 217, 219, 220, 217, 215, 210, 208, 
    204, 200
]
I_mirrored = [220+(220-I[i]) for i in range(45)] + I[45:]
plt.plot(gray, I)
plt.plot(gray, I_mirrored)
plt.show()
plt.plot(gray, [2*np.arcsin(x/max(I_mirrored)) for x in I_mirrored])
plt.show()

# %%
# EX 3 (WRONG)
I = [
    680, 679, 679, 682, 682, 684, 685, 685, 685, 685,
    685, 685, 684, 682, 680, 675, 673, 669, 665, 662,
    661, 658, 656, 653, 650, 648, 647, 646, 645, 644,
    642, 642, 642, 641, 641, 640, 640, 639, 638, 638,
    636, 636, 635, 634, 633, 633, 632, 632, 632, 632,
    635, 636
]
plt.plot(gray, I)

# %%
gray = range(0, 256, 10)
X1 = [
    866, 867, 870, 870, 870, 872, 872, 873, 874, 876, 877, 879, 881, 882, 883, 
    884, 887, 888, 890, 892, 894, 894, 895, 897, 900, 903
]
X2 = [
    918, 919, 919, 919, 920, 922, 924, 924, 925, 926, 927, 929, 930, 932, 933,
    936, 936, 938, 940, 941, 944, 945, 947, 948, 950, 952
]
X3 = [
    970, 970, 971, 971, 973, 973, 974, 976, 976, 977, 979, 980, 982, 983, 985, 
    987, 989, 990, 992, 993, 995, 996, 998, 1000, 1002, 1004
]
plt.plot(gray, X1)
plt.plot(gray, X2)
plt.plot(gray, X3)
